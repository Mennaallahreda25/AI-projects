# %%
"""
Train a deep learning model on facial emotion detection

Dataset from: https://www.kaggle.com/msambare/fer2013
"""
# Out:
# '\nTrain a deep learning model on facial emotion detection\n\nDataset from: https://www.kaggle.com/msambare/fer2013\n'

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
IMG_HEIGHT=48
IMG_WIDTH = 48
batch_size=32

train_data_dir='/content/drive/MyDrive/Instant files /emotion detect short data/train/'
validation_data_dir='/content/drive/MyDrive/Instant files /emotion detect short data/test/'

train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					horizontal_flip=True,
					fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
					train_data_dir,
					color_mode='grayscale',
					target_size=(IMG_HEIGHT, IMG_WIDTH),
					batch_size=batch_size,
					class_mode='categorical',
					shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
							validation_data_dir,
							color_mode='grayscale',
							target_size=(IMG_HEIGHT, IMG_WIDTH),
							batch_size=batch_size,
							class_mode='categorical',
							shuffle=True)

#Verify our generator by plotting a few faces and printing corresponding labels
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']

img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()
##########################################################
# Out:
# Found 350 images belonging to 7 classes.
# Found 350 images belonging to 7 classes.

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())


train_path = "/content/drive/MyDrive/Instant files /emotion detect short data/train/"
test_path = "/content/drive/MyDrive/Instant files /emotion detect short data/test/"

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)

num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)


epochs=50

history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)

model.save('emotion_detection_model_100epochs.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 2,489,095
# Trainable params: 2,489,095
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 10/10 [==============================] - 290s 30s/step - loss: 1.9572 - accuracy: 0.1195 - val_loss: 1.9457 - val_accuracy: 0.1594
# Epoch 2/50
# 10/10 [==============================] - 9s 860ms/step - loss: 1.9477 - accuracy: 0.1258 - val_loss: 1.9452 - val_accuracy: 0.1562
# Epoch 3/50
# 10/10 [==============================] - 9s 953ms/step - loss: 1.9464 - accuracy: 0.1478 - val_loss: 1.9456 - val_accuracy: 0.1500
# Epoch 4/50
# 10/10 [==============================] - 8s 817ms/step - loss: 1.9458 - accuracy: 0.1541 - val_loss: 1.9453 - val_accuracy: 0.1375
# Epoch 5/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.9456 - accuracy: 0.1415 - val_loss: 1.9430 - val_accuracy: 0.1531
# Epoch 6/50
# 10/10 [==============================] - 9s 945ms/step - loss: 1.9455 - accuracy: 0.1384 - val_loss: 1.9386 - val_accuracy: 0.1969
# Epoch 7/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.9448 - accuracy: 0.1730 - val_loss: 1.9437 - val_accuracy: 0.1688
# Epoch 8/50
# 10/10 [==============================] - 9s 900ms/step - loss: 1.9440 - accuracy: 0.1667 - val_loss: 1.9091 - val_accuracy: 0.1594
# Epoch 9/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.9358 - accuracy: 0.1824 - val_loss: 1.8945 - val_accuracy: 0.2656
# Epoch 10/50
# 10/10 [==============================] - 8s 816ms/step - loss: 1.8855 - accuracy: 0.2421 - val_loss: 1.8628 - val_accuracy: 0.2094
# Epoch 11/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.8875 - accuracy: 0.2264 - val_loss: 1.8637 - val_accuracy: 0.2344
# Epoch 12/50
# 10/10 [==============================] - 8s 823ms/step - loss: 1.8663 - accuracy: 0.2673 - val_loss: 1.8074 - val_accuracy: 0.3000
# Epoch 13/50
# 10/10 [==============================] - 8s 828ms/step - loss: 1.8382 - accuracy: 0.2438 - val_loss: 1.7948 - val_accuracy: 0.2719
# Epoch 14/50
# 10/10 [==============================] - 8s 808ms/step - loss: 1.8420 - accuracy: 0.2704 - val_loss: 1.7799 - val_accuracy: 0.3000
# Epoch 15/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.8433 - accuracy: 0.2421 - val_loss: 1.7542 - val_accuracy: 0.3625
# Epoch 16/50
# 10/10 [==============================] - 7s 705ms/step - loss: 1.8092 - accuracy: 0.3019 - val_loss: 1.7172 - val_accuracy: 0.3156
# Epoch 17/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.7701 - accuracy: 0.2893 - val_loss: 1.6952 - val_accuracy: 0.3469
# Epoch 18/50
# 10/10 [==============================] - 8s 830ms/step - loss: 1.7766 - accuracy: 0.2893 - val_loss: 1.6778 - val_accuracy: 0.3656
# Epoch 19/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.7575 - accuracy: 0.3019 - val_loss: 1.6681 - val_accuracy: 0.3719
# Epoch 20/50
# 10/10 [==============================] - 9s 974ms/step - loss: 1.7729 - accuracy: 0.3145 - val_loss: 1.6960 - val_accuracy: 0.3250
# Epoch 21/50
# 10/10 [==============================] - 7s 703ms/step - loss: 1.7563 - accuracy: 0.3522 - val_loss: 1.6531 - val_accuracy: 0.4250
# Epoch 22/50
# 10/10 [==============================] - 9s 937ms/step - loss: 1.7339 - accuracy: 0.3365 - val_loss: 1.6534 - val_accuracy: 0.3625
# Epoch 23/50
# 10/10 [==============================] - 9s 951ms/step - loss: 1.7491 - accuracy: 0.3239 - val_loss: 1.7803 - val_accuracy: 0.3125
# Epoch 24/50
# 10/10 [==============================] - 8s 820ms/step - loss: 1.7670 - accuracy: 0.3208 - val_loss: 1.6354 - val_accuracy: 0.3969
# Epoch 25/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.7269 - accuracy: 0.3176 - val_loss: 1.5864 - val_accuracy: 0.4094
# Epoch 26/50
# 10/10 [==============================] - 8s 816ms/step - loss: 1.6878 - accuracy: 0.3113 - val_loss: 1.5869 - val_accuracy: 0.4000
# Epoch 27/50
# 10/10 [==============================] - 8s 814ms/step - loss: 1.6495 - accuracy: 0.3648 - val_loss: 1.5372 - val_accuracy: 0.4031
# Epoch 28/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.6515 - accuracy: 0.3868 - val_loss: 1.5229 - val_accuracy: 0.4250
# Epoch 29/50
# 10/10 [==============================] - 8s 825ms/step - loss: 1.7121 - accuracy: 0.3585 - val_loss: 1.5533 - val_accuracy: 0.4156
# Epoch 30/50
# 10/10 [==============================] - 8s 819ms/step - loss: 1.6342 - accuracy: 0.3962 - val_loss: 1.5152 - val_accuracy: 0.4156
# Epoch 31/50
# 10/10 [==============================] - 11s 1s/step - loss: 1.6619 - accuracy: 0.4057 - val_loss: 1.4739 - val_accuracy: 0.4469
# Epoch 32/50
# 10/10 [==============================] - 7s 699ms/step - loss: 1.6381 - accuracy: 0.3522 - val_loss: 1.5830 - val_accuracy: 0.3313
# Epoch 33/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.7127 - accuracy: 0.3270 - val_loss: 1.4879 - val_accuracy: 0.4437
# Epoch 34/50
# 10/10 [==============================] - 11s 1s/step - loss: 1.6610 - accuracy: 0.3711 - val_loss: 1.4226 - val_accuracy: 0.4844
# Epoch 35/50
# 10/10 [==============================] - 8s 818ms/step - loss: 1.6116 - accuracy: 0.4057 - val_loss: 1.3984 - val_accuracy: 0.4781
# Epoch 36/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.5749 - accuracy: 0.4057 - val_loss: 1.3932 - val_accuracy: 0.5031
# Epoch 37/50
# 10/10 [==============================] - 8s 817ms/step - loss: 1.5698 - accuracy: 0.4245 - val_loss: 1.3754 - val_accuracy: 0.5125
# Epoch 38/50
# 10/10 [==============================] - 8s 788ms/step - loss: 1.5938 - accuracy: 0.4057 - val_loss: 1.3328 - val_accuracy: 0.5500
# Epoch 39/50
# 10/10 [==============================] - 11s 1s/step - loss: 1.5174 - accuracy: 0.4371 - val_loss: 1.3351 - val_accuracy: 0.5188
# Epoch 40/50
# 10/10 [==============================] - 8s 825ms/step - loss: 1.5715 - accuracy: 0.3868 - val_loss: 1.3557 - val_accuracy: 0.4906
# Epoch 41/50
# 10/10 [==============================] - 7s 708ms/step - loss: 1.5262 - accuracy: 0.4281 - val_loss: 1.2736 - val_accuracy: 0.5469
# Epoch 42/50
# 10/10 [==============================] - 13s 1s/step - loss: 1.4772 - accuracy: 0.4214 - val_loss: 1.3365 - val_accuracy: 0.4969
# Epoch 43/50
# 10/10 [==============================] - 11s 1s/step - loss: 1.5142 - accuracy: 0.3962 - val_loss: 1.3208 - val_accuracy: 0.5437
# Epoch 44/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.4944 - accuracy: 0.4560 - val_loss: 1.2172 - val_accuracy: 0.5500
# Epoch 45/50
# 10/10 [==============================] - 8s 815ms/step - loss: 1.4343 - accuracy: 0.4623 - val_loss: 1.1935 - val_accuracy: 0.5500
# Epoch 46/50
# 10/10 [==============================] - 8s 822ms/step - loss: 1.4317 - accuracy: 0.4563 - val_loss: 1.1784 - val_accuracy: 0.5688
# Epoch 47/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.4466 - accuracy: 0.4465 - val_loss: 1.2057 - val_accuracy: 0.5938
# Epoch 48/50
# 10/10 [==============================] - 8s 820ms/step - loss: 1.4240 - accuracy: 0.4780 - val_loss: 1.1962 - val_accuracy: 0.5688
# Epoch 49/50
# 10/10 [==============================] - 10s 1s/step - loss: 1.3647 - accuracy: 0.4969 - val_loss: 1.1439 - val_accuracy: 0.5875
# Epoch 50/50
# 10/10 [==============================] - 11s 1s/step - loss: 1.3800 - accuracy: 0.4656 - val_loss: 1.1442 - val_accuracy: 0.5562

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model


#Test the model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# 1/1 [==============================] - 0s 413ms/step
# Accuracy =  0.53125
