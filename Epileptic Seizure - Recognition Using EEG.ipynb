# %% [markdown]
# # Epileptic Seizure Recognition

# %% [markdown]
# # Project 1: Machine Learning Algorithms for Epileptic Seizures

# %% [markdown]
# **Dataset**
# https://www.kaggle.com/harunshimanto/epileptic-seizure-recognition
#
# **Dataset name**
# Epileptic Seizure Recognition epileptic seizure detection
#
# **Dataset file **
# Epileptic Seizure Recognition.csv
#
# **number means in dataset of FX (Y)**
# • 5 - eyes open, means when they were recording the EEG signal of the brain the patient had their eyes open
# • 4 - eyes closed, means when they were recording the EEG signal the patient had their eyes closed
# • 3 - Yes they identify where the region of the tumor was in the brain and recording the EEG activity from the healthy brain area
# • 2 - They recorder the EEG from the area where the tumor was located
# • 1 - Recording of seizure activity
#
# All subjects falling in classes 2, 3, 4, and 5 are subjects who did not have epileptic seizure. Only subjects in class 1 have epileptic seizure.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sn 
import matplotlib.pyplot as plt

ESR = pd.read_csv('Epileptic Seizure Recognition.csv')
print (ESR. head ( ))
cols = ESR. columns
tgt = ESR.y
tgt [tgt>1]=0
ax = sn. countplot (tgt, label="Count")
plt.show ()
non_seizure, seizure = tgt. value_counts ()
print('The number of trials for the non-seizure class is:', non_seizure)
print ('The number of trials for the seizure class is:', seizure)
print (ESR.isnull().sum())
print (ESR.info())
X = ESR.iloc [:,1:179].values
print (X.shape)

plt. subplot (511)
plt.plot (X[1,:])
pit.title('Classes')
plt.ylabel('uV')
pit.subplot (512)
plt.plot (X[7, :])
plt.subplot(513)
plt.plot (X[12,:])
plt.subplot (514)
plt.plot(X[0, : ])
plt.subplot(515)
plt.plot (X[2,:])
plt.xlabel ('Samples')
plt.show ()

y = ESR. iloc[:, 179]. values
print (y)
У[у>1]=0
print(y)

from sklearn. model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler ( )
X_train = sc.fit_transform(X_train)
X test = sc.transform(X test)
#- -
from sklearn. linear_model import LogisticRegression
c1f = LogisticRegression ()
clf.fit (X_train, y_train)
y_pred_log_reg = clf.predict (X_test)
acc_log_reg = round(clf.score(X_test, y_test) * 100, 2)
print (str(acc_log_reg) + ' %')

#--
from sklearn.svm import SVC
clf = SVC ()
clf.fit(X_train, y_train)
y_pred_svc = clf.predict (X_test)
acc_svc = round(clf.score (X_test, y_test) * 100, 2)
print (str(acc_svc) + '%')
#--
from sklearn. svm import sC, Linearsvc
clf = LinearSVC()
clf.fit(X_train, y_train)
y_pred_linear_svc = clf.predict (X_test)
acc_linear_svc = round(clf.score(X_test, y_test) * 100, 2)
print (str (acc_linear_svc) + '%*)


 -
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier ()
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
acc_knn = round(clf.score(X_test, y_test) * 100,
print (str (acc_knn)+'%*)
#-
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB
c1f.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
acc_gnb = round (clf.score(X_test, y_test) * 100, 2)
print (str (acc_gnb) + '%')
#-
from sklearn.decomposition import PCA
pca = PCA()
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pa.transform(X_test)
acc_PCA = round(pa.score (X_test, y_test).)
print (str(acc_PCA) + '%')

#Importing keras Libraries and packages import keras
from keras.models import Sequential from keras.layers import Dense
classifier = Sequential ()
classifier.add(Dense(output_dim = 80, init = 'uniform', activation = 'relu', input_dim = 178))
classifier.add(Dense(output_dim = 80, init = 'uniform', activation = 'relu'))
classifier.add (Dense (output_dim = 1, init = 'uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#Fitting the ANN to the training set
history=classifier.fit(X_train, y_train, batch_size = 10, b_epoch = 100)
# Predicting the Test set results
print("Evaluation: ")
mse, acc_ANN = classifier.evaluate (X_test, y_test)
acc ANN = acc ANN * 100
print (str(acc ANN) + '%")


-models = pd.DataFrame ( {
'Model': ['Logistic Regression', 'Support Vector Machines', 'ANN'
'KNN' .
'Naive Bayes'
'Principal Component Analysis'],
'Score': [acc_log_reg, acc_svc, acc_ANN, acc_knn, acc_gnb, acc_PCA]
})
print (models.sort_values (by='Score', ascending=False))

# %% [markdown]
# # Project 2 : Deep Learning with Python: Epileptic Seizure Detection on EEG

# %%
# Dataset
https://archive.ics.uci.edu/ml/datasets/Epileptic+Seizure+Recognition
Machine Learning Repository
Epileptic Seizure Recognition Data Set
data = "data.csv""

# %%
import pandas as pd
df = pd.read_csv(data, header=0, index_col=0)
print (df. head())
print (df.info())

dfr"seizure" = 0
for i in range (11500):
    if df["y" ][i] == 1:
        df["seizure"][i]=1
    else:
        df["seizure"][i] = 0

import matplotlib.pyplot as plt
# plotting an epileptic wave form
plt.plot (range (178), df.iloc [11496, 0:178])
plt.show()
plt.plot (range (178), df.iloc[0,0:178])
plt.show()


# create df1 which only contains the waveform data points
df1 = df. drop (["seizure", "y"], axis=1)
# 1. parse the data
import numpy as np
wave = np. zeros ((11500, 178))
_index =0
for index, row in df1.iterrows ():
    wave [_ index,:] = row
    _index+=1
# print the wave. shape to make sure we parsed the data correctly
print (wave.shape)
# 2. standardize the data such that it has mean of 0 and standard deviation of
mean = wave. mean (axis=0)
wave -= mean
std = wave.std (axis=0)
wave /= std
# 3. create the target numpy array
target = df ["seizure"].values


from sklearn.metrics import roc_curve, auc
Y_pred = model.predict (×_test).ravel ()
fpr_keras, tpr_keras, thresholds_keras = roc_curve (y_test, y_pred)
AUC = auc (fpr_keras, tpr_keras)
pit.plot (fpr_keras, tpr_keras, label='Keras Model(area = {:.3f})'.format (AUC))
plt.xlabel ('False positive Rate')
pit.ylabel ('True positive Rate')
pit.title('ROC curve')
plt.legend(loc='best')
plt.show()


acc = history.history['acc' ]
val_acc = history.history[ 'val_acc']
loss = history.history['loss']
val_loss = historg.history[ 'val_loss']
epochs = range(len (acc))
pit.plot (epochs, acc, 'b', label='Training acc') 
plt.plot(epochs, val_acc, 'p', label='Validation acc')
plt. title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss') 
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Resources:
#
# https://www.kaggle.com/harunshimanto/machine-learning-algorithms-for-epileptic-seizures
#
# https://medium.com/@steven827/deep-learning-with-python-epileptic-seizure-detection-on-eeg-41dcb6a0b64c
